# %%
# %load_ext sql

# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv")

# %%
df.head()
# Out:
#          Date Time (UTC) Booster_Version  Launch_Site  \
# 0  04-06-2010   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1  08-12-2010   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2  22-05-2012   07:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3  08-10-2012   00:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4  01-03-2013   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome     Landing _Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# ...

# %%
df['Date1']=df['Date']+' '+df['Time (UTC)']

# %%
df = df.drop('Date',axis=1)

# %%
df = df.drop('Time (UTC)',axis=1)

# %%
df.head()
# Out:
#   Booster_Version  Launch_Site  \
# 0  F9 v1.0  B0003  CCAFS LC-40
# 1  F9 v1.0  B0004  CCAFS LC-40
# 2  F9 v1.0  B0005  CCAFS LC-40
# 3  F9 v1.0  B0006  CCAFS LC-40
# 4  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome     Landing _Outcome  \
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# 2  LEO (ISS)      NASA (COTS)         Success           No attempt
# 3  LEO (ISS)       NASA (CRS)         Success           No attempt
# ...

# %%
first_column = df.pop('Date1')

# %%
df.insert(0,"Date1",first_column)

# %%
df['Date1'] = pd.to_datetime(df['Date1'], format='%d-%m-%Y %H:%M:%S')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date1              101 non-null    datetime64[ns]
#  1   Booster_Version    101 non-null    object
#  2   Launch_Site        101 non-null    object
#  3   Payload            101 non-null    object
#  4   PAYLOAD_MASS__KG_  101 non-null    int64
#  5   Orbit              101 non-null    object
#  6   Customer           101 non-null    object
#  7   Mission_Outcome    101 non-null    object
#  8   Landing _Outcome   101 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 7.2+ KB

# %%
df.columns.str.len()
# Out:
# Int64Index([5, 15, 11, 7, 17, 5, 8, 15, 16], dtype='int64')

# %%
df.head()
# Out:
#                 Date1 Booster_Version  Launch_Site  \
# 0 2010-06-04 18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1 2010-12-08 15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2 2012-05-22 07:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3 2012-10-08 00:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4 2013-03-01 15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  PAYLOAD_MASS__KG_  \
# 0               Dragon Spacecraft Qualification Unit                  0
# 1  Dragon demo flight C1, two CubeSats, barrel of...                  0
# 2                              Dragon demo flight C2                525
# 3                                       SpaceX CRS-1                500
# 4                                       SpaceX CRS-2                677
#
#        Orbit         Customer Mission_Outcome     Landing _Outcome
# 0        LEO           SpaceX         Success  Failure (parachute)
# 1  LEO (ISS)  NASA (COTS) NRO         Success  Failure (parachute)
# ...

# %%
records_as_list = list(df.values)

records =[l.tolist() for l in records_as_list]

records
# Out:
# [[Timestamp('2010-06-04 18:45:00'),
#   'F9 v1.0  B0003',
#   'CCAFS LC-40',
#   'Dragon Spacecraft Qualification Unit',
#   0,
#   'LEO',
#   'SpaceX',
#   'Success',
#   'Failure (parachute)'],
#  [Timestamp('2010-12-08 15:43:00'),
#   'F9 v1.0  B0004',
#   'CCAFS LC-40',
#   'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese',
#   0,
#   'LEO (ISS)',
#   'NASA (COTS) NRO',
#   'Success',
#   'Failure (parachute)'],
#  [Timestamp('2012-05-22 07:44:00'),
#   'F9 v1.0  B0005',
#   'CCAFS LC-40',
#   'Dragon demo flight C2',
#   525,
#   'LEO (ISS)',
#   'NASA (COTS)',
#   'Success',
#   'No attempt'],
#  [Timestamp('2012-10-08 00:35:00'),
#   'F9 v1.0  B0006',
#   'CCAFS LC-40',
#   'SpaceX CRS-1',
#   500,
#   'LEO (ISS)',
#   'NASA (CRS)',
#   'Success',
#   'No attempt'],
#  [Timestamp('2013-03-01 15:10:00'),
#   'F9 v1.0  B0007',
#   'CCAFS LC-40',
#   'SpaceX CRS-2',
#   677,
#   'LEO (ISS)',
#   'NASA (CRS)',
#   'Success',
#   'No attempt'],
# ...

# %%
import cx_Oracle
con = cx_Oracle.connect('practice/practice@localhost:1521/xe')
    # Now execute the sqlquery
cursor = con.cursor()
 
    # drop a table employee
cursor.execute("drop table spacextbl")

# %%
import cx_Oracle
 
# Create a table in Oracle database
try:
 
    con = cx_Oracle.connect('practice/practice@localhost:1521/xe')
    print(con.version)
 
    # Now execute the sqlquery
    cursor = con.cursor()
 
    # Creating a table employee
    cursor.execute(
        "create table spacextbl(date1 date, Booster_Version varchar(20), Launch_Site varchar(40), Payload varchar(100), PAYLOAD_MASS__KG_ number(38), Orbit varchar(40), Customer varchar(100), Mission_Outcome varchar(40), Landing_Outcome varchar(40))")
 
    print("Table Created successfully")
 
except cx_Oracle.DatabaseError as e:
    print("There is a problem with Oracle", e)
 
# by writing finally if any error occurs
# then also we can close the all database operation
finally:
    if cursor:
        cursor.close()
    if con:
        con.close()
# Out:
# 11.2.0.2.0
# Table Created successfully

# %%
import cx_Oracle
 
# Load data from a csv file into Oracle table using executemany
try:
    con = cx_Oracle.connect('practice/practice@localhost:1521/xe')
 
except cx_Oracle.DatabaseError as er:
    print('There is an error in Oracle database:', er)
 
else:
    try:
        cur = con.cursor()
        data = records
 
        cur = con.cursor()
        # Inserting multiple records into employee table
        # (:1,:2,:3) are place holders. They pick data from a list supplied as argument
        cur.executemany('insert into spacextbl values(:1,:2,:3,:4,:5,:6,:7,:8,:9)', data)
 
    except cx_Oracle.DatabaseError as er:
        print('There is an error in Oracle database:', er)
 
    except Exception as er:
        print(er)
 
    else:
        # To commit the transaction manually
        con.commit()
        print('Multiple records are inserted successfully')
 
finally:
    if cur:
        cur.close()
    if con:
        con.close()
# Out:
# Multiple records are inserted successfully

# %%
# %sql oracle://practice:practice@localhost:1521/xe

# %%
# %sql
# Out:
#  * oracle://practice:***@localhost:1521/xe

# %%
# %sql select * from spacextbl
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [(datetime.datetime(2010, 6, 4, 18, 45), 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  (datetime.datetime(2010, 12, 8, 15, 43), 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  (datetime.datetime(2012, 5, 22, 7, 44), 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  (datetime.datetime(2012, 10, 8, 0, 35), 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  (datetime.datetime(2013, 3, 1, 15, 10), 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
# ...

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# **Note: If the column names are in mixed case enclose it in double quotes
#    For Example "Landing_Outcome"**
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql select distinct(launch_site) from spacextbl
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [('KSC LC-39A',), ('CCAFS SLC-40',), ('CCAFS LC-40',), ('VAFB SLC-4E',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql select * from spacextbl where launch_site like 'CCA%' and rownum<=5
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [(datetime.datetime(2010, 6, 4, 18, 45), 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  (datetime.datetime(2010, 12, 8, 15, 43), 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  (datetime.datetime(2012, 5, 22, 7, 44), 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  (datetime.datetime(2012, 10, 8, 0, 35), 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  (datetime.datetime(2013, 3, 1, 15, 10), 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt')]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql select sum(payload_mass__kg_) from spacextbl where customer ='NASA (CRS)'
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [(45596,)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql select avg(payload_mass__kg_) from spacextbl where booster_version='F9 v1.1'
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [(Decimal('2928.4'),)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first succesful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# %sql select min(date1) from spacextbl where landing_outcome like'%Success%'
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [(datetime.datetime(2015, 12, 22, 1, 29),)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql select distinct(landing_outcome) from spacextbl
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [('Success (ground pad)',),
#  ('Failure',),
#  ('Failure (parachute)',),
#  ('Controlled (ocean)',),
#  ('Success (drone ship)',),
#  ('No attempt',),
#  ('Uncontrolled (ocean)',),
#  ('Precluded (drone ship)',),
#  ('No attempt ',),
#  ('Success',),
#  ('Failure (drone ship)',)]

# %%
# %sql select booster_version from spacextbl where landing_outcome='Success (drone ship)' and payload_mass__kg_ between 4000 and 6000
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [('F9 FT B1022',), ('F9 FT B1026',), ('F9 FT  B1021.2',), ('F9 FT  B1031.2',)]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %sql select count(*),mission_outcome from spacextbl group by mission_outcome
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [(1, 'Success (payload status unclear)'),
#  (1, 'Success '),
#  (98, 'Success'),
#  (1, 'Failure (in flight)')]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %sql select booster_version from spacextbl where payload_mass__kg_ =(select max(payload_mass__kg_)from spacextbl)
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2 ',),
#  ('F9 B5 B1058.3 ',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7 ',)]

# %% [markdown]
# ### Task 9
#
#
# ##### List the records which will display the month names, failure landing_outcomes in drone ship ,booster versions, launch_site for the months in year 2015.
#
# **Note: SQLLite does not support monthnames. So you need to use  substr(Date, 4, 2) as month to get the months and substr(Date,7,4)='2015' for year.**

# %%
# %sql select to_char(date1, 'Month'),landing_outcome,booster_version,launch_site from spacextbl where landing_outcome='Failure (drone ship)' and EXTRACT(YEAR FROM date1)=2015
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [('January  ', 'Failure (drone ship)', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  ('April    ', 'Failure (drone ship)', 'F9 v1.1 B1015', 'CCAFS LC-40')]

# %% [markdown]
# ### Task 10
#
#
#
#
# ##### Rank the  count of  successful landing_outcomes between the date 04-06-2010 and 20-03-2017 in descending order.

# %%
# %sql select count(*),landing_outcome from spacextbl where (to_char(cast(date1 as date),'YYYY-MM-DD')) between '2010-06-04' and '2017-03-20' group by landing_outcome having landing_outcome like'%Succes%'order by count(*) desc
# Out:
#  * oracle://practice:***@localhost:1521/xe
# 0 rows affected.
# [(5, 'Success (drone ship)'), (3, 'Success (ground pad)')]
